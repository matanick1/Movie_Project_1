# %%
import pandas as pd

# %%
# read the csv file
df = pd.read_csv('most_recent.csv')
df
# Out:
#                                          Title  Year  Inflation Rank  \
# 0                           Gone With The Wind  1939               1
# 1             Star Wars Episode IV: A New Hope  1977               2
# 2                           The Sound Of Music  1965               3
# 3                    ET: The Extra Terrestrial  1982               4
# 4                                      Titanic  1997               5
# ..                                         ...   ...             ...
# 95             One Flew Over The Cuckoo's Nest  1975              97
# 96                                        MASH  1970              98
# 97        Indiana Jones And The Temple Of Doom  1984              99
# 98  Star Wars Episode II: Attack Of The Clones  2002             100
# 99                      Avengers Age Of Ultron  2015             101
#
#     Adj. Domestic Lifetime Gross  Est. Num Tickets  Worldwide Rank  \
# 0                     1895421694         202286200             318
# ...

# %%
print(df.dtypes)
# Out:
# Title                            object
# Year                              int64
# Inflation Rank                    int64
# Adj. Domestic Lifetime Gross      int64
# Est. Num Tickets                  int64
# Worldwide Rank                    int64
# Worldwide Lifetime Gross          int64
# Domestic Lifetime Gross         float64
# Domestic %                        int64
# Foreign Lifetime Gross            int64
# Foreign %                         int64
# Production Budget               float64
# Profit                          float64
# dtype: object

# %%
# convert the domestic lifetime gross column to an integer
df['Domestic Lifetime Gross'] = df['Domestic Lifetime Gross'].astype(int)
df.head()
# Out:
#                               Title  Year  Inflation Rank  \
# 0                Gone With The Wind  1939               1
# 1  Star Wars Episode IV: A New Hope  1977               2
# 2                The Sound Of Music  1965               3
# 3         ET: The Extra Terrestrial  1982               4
# 4                           Titanic  1997               5
#
#    Adj. Domestic Lifetime Gross  Est. Num Tickets  Worldwide Rank  \
# 0                    1895421694         202286200             318
# 1                    1668979715         178119500             102
# 2                    1335086324         142485200               0
# 3                    1329174791         141854300               0
# 4                    1270101626         135549800               3
#
#    Worldwide Lifetime Gross  Domestic Lifetime Gross  Domestic %  \
# 0                 402352579                200882193          50
# 1                 775398007                460998507          59
# ...

# %%
# convert the production budget and profit columns to an integer
df['Production Budget'] = df['Production Budget'].astype(int)
df['Profit'] = df['Profit'].astype(int)
df.head()
# Out:
#                               Title  Year  Inflation Rank  \
# 0                Gone With The Wind  1939               1
# 1  Star Wars Episode IV: A New Hope  1977               2
# 2                The Sound Of Music  1965               3
# 3         ET: The Extra Terrestrial  1982               4
# 4                           Titanic  1997               5
#
#    Adj. Domestic Lifetime Gross  Est. Num Tickets  Worldwide Rank  \
# 0                    1895421694         202286200             318
# 1                    1668979715         178119500             102
# 2                    1335086324         142485200               0
# 3                    1329174791         141854300               0
# 4                    1270101626         135549800               3
#
#    Worldwide Lifetime Gross  Domestic Lifetime Gross  Domestic %  \
# 0                 402352579                200882193          50
# 1                 775398007                460998507          59
# ...

# %%
# create an updated csv file
df.to_csv('most_recent.csv', index=False)

# %%
# replace all 0 values in the dataframe with blank cells
df = df.replace(0, '')
df.head()
# Out:
#                               Title  Year  Inflation Rank  \
# 0                Gone With The Wind  1939               1
# 1  Star Wars Episode IV: A New Hope  1977               2
# 2                The Sound Of Music  1965               3
# 3         ET: The Extra Terrestrial  1982               4
# 4                           Titanic  1997               5
#
#    Adj. Domestic Lifetime Gross  Est. Num Tickets Worldwide Rank  \
# 0                    1895421694         202286200            318
# 1                    1668979715         178119500            102
# 2                    1335086324         142485200
# 3                    1329174791         141854300
# 4                    1270101626         135549800              3
#
#   Worldwide Lifetime Gross  Domestic Lifetime Gross Domestic %  \
# 0                402352579                200882193         50
# 1                775398007                460998507         59
# 2                                         159287539
# ...

# %%
# create a new csv file
df.to_csv('most_recent_with_blanks.csv', index=False)
